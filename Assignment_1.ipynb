# %% [markdown]
# <a href="https://colab.research.google.com/github/hongnhung991022-svg/Assignment1-Project-Python/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
   getfile = input("Enter a class file to grade (i.e. class1 for class1.txt):")
   filename = f"{getfile}.txt"
   with open(filename) as f:
      s = f.read()
      print(s)
      print(f"\n\nSuccessfully opened {filename}")
except FileNotFoundError:
  print(f"File '{filename}' cannot be opened. Please ensure the file exists.")
# Out:
# Enter a class file to grade (i.e. class1 for class1.txt):class2
# N00000021,B,A,C,D,C,C,D,D,C,C,D,B,,B,A,C,B,,A,D,A,A,B,D,
# N00000022,B,A,D,A,C,B,D,D,C,C,D,B,A,B,A,,B,A,A,C,A,A,B,A,D
# N00000023,,A,D,D,C,B,D,A,C,C,,C,,B,A,C,B,D,A,C,A,A
# N00000024,C,C,D,D,C,B,,A,C,C,D,B,A,B,,C,B,D,A,C,A,B,B,,D
# N0000002,B,A,D,D,C,B,D,A,C,D,D,D,A,,A,C,D,,A,C,A,A,B,D,D
# N00000026,B,C,D,D,C,D,B,A,C,D,D,,A,B,A,C,B,D,,C,A,A,B,D,D
# NA0000027,B,A,D,D,,B,,A,C,B,D,B,A,,A,C,B,D,A,,A,A,B,D,D
# N00000028,B,A,D,D,D,B,D,A,C,C,,,A,B,A,,B,D,C,C,A,A,B,C,D
# N00000029,B,A,D,D,C,A,D,A,C,C,D,B,A,B,A,C,B,,,C,A,A,B,D,D
# N00000030,A,A,D,D,C,B,D,,C,C,D,B,A,B,A,C,B,B,A,C,A,,B,D,D
# N00000031,B,,D,D,C,B,D,A,A,C,D,C,A,B,A,C,B,C,A,C,C,A,B,D,D
# N00000032,B,A,D,D,C,B,D,A,C,C,D,,A,A,A,C,B,D,A,C,,A,B,D,D
# N00000033,B,A,D,D,C,,D,A,C,B,D,B,A,B,C,C,C,D,A,C,A,,B,D,D
# N00000034,B,,D,,C,B,A,A,C,C,D,B,A,,A,C,B,A,B,C,A,,B,D,D
# N00000035,B,A,D,D,B,B,,A,C,,D,B,A,B,A,A,B,D,A,C,A,C,B,D,D,A,A
# N00000036,B,A,D,D,C,B,D,A,C,B,A,C,A,B,A,C,B,D,A,C,A,A,B,,
# N00000037,B,A,D,D,C,,D,A,C,C,D,,A,B,A,A,B,D,A,C,,,,D,D
# N00000038,,A,D,,C,B,D,A,A,C,D,B,A,B,A,C,B,D,,C,A,D,B,D,C
# N00000039,B,A,D,D,C,A,B,A,C,C,D,B,A,D,A,,C,D,A,B,A,A,B,A,D
# N00000040,B,A,,D,C,B,D,D,C,C,C,B,A,B,A,C,A,,A,C,A,,B,D,D
# N00000041,,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,B,A,B,D,D
# N00000042,B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D
# N00000043,C,A,D,D,C,B,D,A,C,C,D,B,A,B,C,C,B,D,A,C,A,,B,D,D
# N00000044,B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,A,B,D,A,C,D,A,B,D,D
# N00000045,C,A,A,D,C,B,D,C,,C,D,B,A,B,A,B,B,A,,C,A,A,B,D,D
#
#
# Successfully opened class2.txt

# %%
lines = s.split("\n")
print(lines)
len(lines)
print(f"There are {len(lines)} lines in the file.")
# Out:
# ['N00000021,B,A,C,D,C,C,D,D,C,C,D,B,,B,A,C,B,,A,D,A,A,B,D,', 'N00000022,B,A,D,A,C,B,D,D,C,C,D,B,A,B,A,,B,A,A,C,A,A,B,A,D', 'N00000023,,A,D,D,C,B,D,A,C,C,,C,,B,A,C,B,D,A,C,A,A', 'N00000024,C,C,D,D,C,B,,A,C,C,D,B,A,B,,C,B,D,A,C,A,B,B,,D', 'N0000002,B,A,D,D,C,B,D,A,C,D,D,D,A,,A,C,D,,A,C,A,A,B,D,D', 'N00000026,B,C,D,D,C,D,B,A,C,D,D,,A,B,A,C,B,D,,C,A,A,B,D,D', 'NA0000027,B,A,D,D,,B,,A,C,B,D,B,A,,A,C,B,D,A,,A,A,B,D,D', 'N00000028,B,A,D,D,D,B,D,A,C,C,,,A,B,A,,B,D,C,C,A,A,B,C,D', 'N00000029,B,A,D,D,C,A,D,A,C,C,D,B,A,B,A,C,B,,,C,A,A,B,D,D', 'N00000030,A,A,D,D,C,B,D,,C,C,D,B,A,B,A,C,B,B,A,C,A,,B,D,D', 'N00000031,B,,D,D,C,B,D,A,A,C,D,C,A,B,A,C,B,C,A,C,C,A,B,D,D', 'N00000032,B,A,D,D,C,B,D,A,C,C,D,,A,A,A,C,B,D,A,C,,A,B,D,D', 'N00000033,B,A,D,D,C,,D,A,C,B,D,B,A,B,C,C,C,D,A,C,A,,B,D,D', 'N00000034,B,,D,,C,B,A,A,C,C,D,B,A,,A,C,B,A,B,C,A,,B,D,D', 'N00000035,B,A,D,D,B,B,,A,C,,D,B,A,B,A,A,B,D,A,C,A,C,B,D,D,A,A', 'N00000036,B,A,D,D,C,B,D,A,C,B,A,C,A,B,A,C,B,D,A,C,A,A,B,,', 'N00000037,B,A,D,D,C,,D,A,C,C,D,,A,B,A,A,B,D,A,C,,,,D,D', 'N00000038,,A,D,,C,B,D,A,A,C,D,B,A,B,A,C,B,D,,C,A,D,B,D,C', 'N00000039,B,A,D,D,C,A,B,A,C,C,D,B,A,D,A,,C,D,A,B,A,A,B,A,D', 'N00000040,B,A,,D,C,B,D,D,C,C,C,B,A,B,A,C,A,,A,C,A,,B,D,D', 'N00000041,,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,B,A,B,D,D', 'N00000042,B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D', 'N00000043,C,A,D,D,C,B,D,A,C,C,D,B,A,B,C,C,B,D,A,C,A,,B,D,D', 'N00000044,B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,A,B,D,A,C,D,A,B,D,D', 'N00000045,C,A,A,D,C,B,D,C,,C,D,B,A,B,A,B,B,A,,C,A,A,B,D,D']
# There are 25 lines in the file.

# %%
import re       #regular expression
expected_value = 26  # Define the expected number of values per line

STUDENT_ID_PATTERN = re.compile(r'^N\d{8}$')  # Regex to validate student ID: 'N' followed by 8 digits

def validate_line(line_data, line_number):
    values = line_data.split(',')   # Split the line by comma
    if len(values) != expected_value:   # Check if the number of values is correct
        return False, f"Line {line_number}: Incorrect number of value. Expected {expected_value} , got {len(values)}.  Line content: '{line_data}'"

    student_id_str = values[0]  # Check if the first value (student ID) is valid
    if not STUDENT_ID_PATTERN.match(student_id_str):
        return False, f"Dòng {line_number}: Invalid student ID format. but got: '{student_id_str}'. Line content: '{line_data}'"

    return True, ""

invalid_lines_count = 0

for i, line in enumerate(lines):
    if not line.strip():
        continue

    is_valid, error_message = validate_line(line, i + 1)
    if not is_valid:
        invalid_lines_count += 1
        print(f"[Error] {error_message}")

print("---------------------------------")
print(f"Total number of lines processed: {len(lines)}")
print(f"Total invalid lines of data: {invalid_lines_count}")
# Out:
# [Error] Line 3: Incorrect number of value. Expected 26 , got 23.  Line content: 'N00000023,,A,D,D,C,B,D,A,C,C,,C,,B,A,C,B,D,A,C,A,A'
# [Error] Dòng 5: Invalid student ID format. but got: 'N0000002'. Line content: 'N0000002,B,A,D,D,C,B,D,A,C,D,D,D,A,,A,C,D,,A,C,A,A,B,D,D'
# [Error] Dòng 7: Invalid student ID format. but got: 'NA0000027'. Line content: 'NA0000027,B,A,D,D,,B,,A,C,B,D,B,A,,A,C,B,D,A,,A,A,B,D,D'
# [Error] Line 15: Incorrect number of value. Expected 26 , got 28.  Line content: 'N00000035,B,A,D,D,B,B,,A,C,,D,B,A,B,A,A,B,D,A,C,A,C,B,D,D,A,A'
# ---------------------------------
# Total number of lines processed: 25
# Total invalid lines of data: 4

# %%
answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D"
answer_key = answer_key.split(",")
print(answer_key)

# Initialize a dictionary to store student scores
student_scores = {}

# Iterate through each line in the file to grade valid students
for i, line in enumerate(lines):
    if not line.strip(): # Skip empty lines
        continue

    # Validate the line before grading (assuming validate_line is defined in global scope)
    is_valid, _ = validate_line(line, i + 1)

    if is_valid:
        # Split the line into values
        values = line.split(',')
        student_id = values[0] # First element is the student ID
        student_answers = values[1:] # All subsequent elements are answers

        current_score = 0
        # Iterate through student answers and compare with answer_key
        # Assuming len(student_answers) is equal to len(answer_key) for valid lines
        for j in range(len(answer_key)):
            student_ans = student_answers[j].strip()
            correct_ans = answer_key[j].strip()

            if student_ans == correct_ans:
                current_score += 4 # Correct answer
            elif student_ans == '':
                current_score += 0 # Blank answer
            else:
                current_score -= 1 # Incorrect answer

        student_scores[student_id] = current_score
    # Invalid lines are skipped for grading

# Print the scores for valid students
print("\n--- Student Scores ---")
for student_id, score in student_scores.items():
    print(f"Student ID: {student_id}, Score: {score}")
# Out:
# ['B', 'A', 'D', 'D', 'C', 'B', 'D', 'A', 'C', 'C', 'D', 'B', 'A', 'B', 'A', 'C', 'B', 'D', 'A', 'C', 'A', 'A', 'B', 'D', 'D']
#
# --- Student Scores ---
# Student ID: N00000021, Score: 68
# Student ID: N00000022, Score: 76
# Student ID: N00000024, Score: 73
# Student ID: N00000026, Score: 72
# Student ID: N00000028, Score: 73
# Student ID: N00000029, Score: 87
# Student ID: N00000030, Score: 82
# Student ID: N00000031, Score: 76
# Student ID: N00000032, Score: 87
# Student ID: N00000033, Score: 77
# Student ID: N00000034, Score: 69
# Student ID: N00000036, Score: 77
# Student ID: N00000037, Score: 75
# Student ID: N00000038, Score: 73
# Student ID: N00000039, Score: 66
# Student ID: N00000040, Score: 73
# Student ID: N00000041, Score: 91
# Student ID: N00000042, Score: 100
# Student ID: N00000043, Score: 86
# Student ID: N00000044, Score: 90
# Student ID: N00000045, Score: 67

# %%
num_advanced_students = 0

for student_id, score in student_scores.items():
    if score > 80:
        num_advanced_students += 1

print(f"Total number of students with scores greater than 80: {num_advanced_students}")

import numpy as np

scores = list(student_scores.values())

# Calculate average score
average_score = np.mean(scores)

# Calculate maximum score
max_score = np.max(scores)

# Calculate minimum score
min_score = np.min(scores)

# Calculate range of scores
range_score = max_score - min_score

# Calculate median score
median_score = np.median(scores)

num_questions = len(answer_key)
skipped_counts = [0] * num_questions
incorrect_counts = [0] * num_questions

# Iterate through each line to analyze individual question responses
for i, line in enumerate(lines):
    if not line.strip():
        continue

    is_valid, _ = validate_line(line, i + 1)

    if is_valid:
        values = line.split(',')
        student_answers = values[1:]

        for j in range(num_questions):
            if j < len(student_answers): # Ensure student_answers has an entry for this question
                student_ans = student_answers[j].strip()
                correct_ans = answer_key[j].strip()

                if student_ans == '':
                    skipped_counts[j] += 1
                elif student_ans != correct_ans:
                    incorrect_counts[j] += 1

# Find the most skipped question
most_skipped_question_index = skipped_counts.index(max(skipped_counts))
most_skipped_count = max(skipped_counts)

# Find the most incorrectly answered question
most_incorrect_question_index = incorrect_counts.index(max(incorrect_counts))
most_incorrect_count = max(incorrect_counts)

print(f"\n--- Statistical Analysis of Scores ---")
print(f"Average Score: {average_score:.2f}")
print(f"Maximum Score: {max_score}")
print(f"Minimum Score: {min_score}")
print(f"Range of Scores: {range_score}")
print(f"Median Score: {median_score}")

print(f"\n--- Question Analysis ---")
print(f"Most skipped question: Question {most_skipped_question_index + 1} (skipped by {most_skipped_count} students)")
print(f"Most incorrectly answered question: Question {most_incorrect_question_index + 1} (incorrectly answered by {most_incorrect_count} students)")
# Out:
# Total number of students with scores greater than 80: 7
#
# --- Question Analysis ---
# Most skipped question: Question 22 (skipped by 6 students)
# Most incorrectly answered question: Question 18 (incorrectly answered by 5 students)
#
# --- Statistical Analysis of Scores ---
# Average Score: 78.00
# Maximum Score: 100
# Minimum Score: 66
# Range of Scores: 34
# Median Score: 76.0

# %%
# Read the content of the newly created file to verify
with open(output_filename, 'r') as infile:
    verified_content = infile.read()

print(f"\n--- Content of '{output_filename}' ---")
print(verified_content)

import os

# 1. Extract the base filename from the `filename` variable.
base_filename = os.path.splitext(filename)[0]

# 2. Create a new filename by adding '_grades.txt' to the extracted base name.
output_filename = f"{base_filename}_grades.txt"

# 3. Open this new file in write mode ('w') and save the score.
with open(output_filename, 'w') as outfile:
    for student_id, score in student_scores.items():
        outfile.write(f"{student_id},{score}\n")

print(f"Student scores successfully written to '{output_filename}'")
# Out:
# --- Content of 'class2_grades.txt' ---
# N00000021,68
# N00000022,76
# N00000024,73
# N00000026,72
# N00000028,73
# N00000029,87
# N00000030,82
# N00000031,76
# N00000032,87
# N00000033,77
# N00000034,69
# N00000036,77
# N00000037,75
# N00000038,73
# N00000039,66
# N00000040,73
# N00000041,91
# N00000042,100
# N00000043,86
# N00000044,90
# N00000045,67
#
# Student scores successfully written to 'class2_grades.txt'
